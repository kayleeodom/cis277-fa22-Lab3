# %% [markdown]
# ## Lab 3 - Video Game Reviews

# %%
from math import nan

# %%
import pandas as pd

# %% [markdown]
# ### Import Data

# %%
df = pd.read_csv('imdb-videogames.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                        name  \
# 0           0                  Spider-Man
# 1           1      Red Dead Redemption II
# 2           2          Grand Theft Auto V
# 3           3                  God of War
# 4           4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#   rating   votes                                       plot summary  Action  \
# 0    9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1    9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# ...

# %%
df.shape
# Out:
# (20805, 17)

# %%
df.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0                                 name  \
# 0               0                           Spider-Man
# 1               1               Red Dead Redemption II
# 2               2                   Grand Theft Auto V
# 3               3                           God of War
# 4               4           Uncharted 4: A Thief's End
# ...           ...                                  ...
# 20800       20798  Enjoy Your Power, Enjoy Your Choice
# 20801       20799                           RedSun2020
# 20802       20800                              Shutter
# 20803       20801                    The Music Machine
# 20804       20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# ...

# %%
df.certificate.value_counts()
# Out:
# T            2474
# E            2006
# M            1820
# E10+          814
# Unrated       241
# K-A           229
# Not Rated     184
# AO             32
# GA             26
# EC             25
# CE             13
# 12              9
# PG-13           7
# MA-13           7
# Approved        4
# G               4
# MA-17           3
# PG              3
# TV-MA           2
# Passed          1
# TV-14           1
# Name: certificate, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'url', 'year', 'certificate', 'rating', 'votes',
#        'plot summary', 'Action', 'Adventure', 'Comedy', 'Crime', 'Family',
#        'Fantasy', 'Mystery', 'Sci-Fi', 'Thriller'],
#       dtype='object')

# %% [markdown]
# ### Clean Data

# %% [markdown]
# Clean and Fix Rating

# %%
df.rating.replace("*9.0", "9.0", inplace=True)
df.rating = pd.to_numeric(df.rating)
df.rating.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0        9.2
# 1        9.7
# 2        9.5
# 3        9.6
# 4        9.5
#         ...
# 20800    NaN
# 20801    NaN
# 20802    NaN
# 20803    NaN
# 20804    NaN
# Name: rating, Length: 20805, dtype: float64>

# %% [markdown]
# Clean and Fix Votes

# %%
df.votes = df.votes.str.replace(',','')
df.votes = pd.to_numeric(df.votes)
df.votes.mean()
# Out:
# 630.9875883468368

# %% [markdown]
# Clean and fix Sci-fi name and plot summary name

# %%
df.columns = ['Unnamed: 0', 'name', 'url', 'year', 'certificate', 'rating', 'votes',
       'plot_summary', 'Action', 'Adventure', 'Comedy', 'Crime', 'Family',
       'Fantasy', 'Mystery', 'Sci_Fi', 'Thriller']

# %% [markdown]
# #### Questions

# %% [markdown]
# #### 1. What is the average rating for Action games?

# %%
dar = df[(df.Action)].rating.mean()
dar
# Out:
# 7.069257468699611

# %% [markdown]
# #### 2. What is the average rating of games after 2010? What is the average rating of games before (and including) 2010?

# %% [markdown]
# After 2010

# %%
mask = df.year > 2010
mask
df[mask].rating.mean()
# Out:
# 7.119838056680145

# %% [markdown]
# Before and including 2010

# %%
mask = df.year <= 2010
mask
df[mask].rating.mean()
# Out:
# 7.006822480410717

# %% [markdown]
# #### 3. What games include "Fallout" in their title?

# %%
games = df[df.name.str.contains("Fallout")]
games
# Out:
#        Unnamed: 0                                         name  \
# 29             29                           Fallout: New Vegas
# 37             37                                    Fallout 4
# 115           115                                    Fallout 3
# 207           207                                   Fallout 76
# 340           340    Fallout: A Post-Nuclear Role-Playing Game
# 437           437  Fallout 2: A Post-Nuclear Role-Playing Game
# 1062         1060                        Fallout: The Frontier
# 1233         1231        Fallout Tactics: Brotherhood of Steel
# 1872         1870           Fallout: New Vegas - Honest Hearts
# 1964         1962                         Fallout 4: New Vegas
# 2003         2001                Fallout: Brotherhood of Steel
# 2117         2115         Fallout: New Vegas - Old World Blues
# 2170         2168                    Fallout Legacy Collection
# 2362         2360            Fallout: New Vegas - Simply Uncut
# ...

# %% [markdown]
# #### 4. What is the most common certificate for Sci-Fi games?

# %%
# only wanna show true (because that means they are under Sci-Fi games)
df.groupby('Sci_Fi')['certificate'].agg(pd.Series.mode)
# gave most common certificate for Sci-Fi games and games that aren't Sci-Fi
# Out:
# Sci_Fi
# False    T
# True     T
# Name: certificate, dtype: object

# %% [markdown]
# #### 5. What percent of Thiller games have M or AO certificate?

# %%
# narrow down to thriller games
# then narrow down to just games that have M or AO certficate
# then find the percentage of Thriller games with it

thriller_m_ao = df[(df.Thriller==True) & (df.certificate=='M') | (df.certificate=='AO')]
print("Number of Thrillers with M or AO:", len(thriller_m_ao))

thriller = df[(df.Thriller==True)]
print("Total number of Thrillers:", len(thriller))

len(thriller_m_ao) / len(thriller)
# Out:
# Number of Thrillers with M or AO: 200
# Total number of Thrillers: 523
# 0.3824091778202677

# %% [markdown]
# #### 6. What is the mean and median rating for Family games? for Action games?

# %% [markdown]
# Family

# %%
df.groupby('Family').rating.agg(['mean','median'])
# Out:
#             mean  median
# Family
# False   7.104427     7.3
# True    6.686450     6.9

# %% [markdown]
# Action

# %%
df.groupby('Action').rating.agg(['mean','median'])
# Out:
#             mean  median
# Action
# False   6.998812     7.2
# True    7.069257     7.2

# %% [markdown]
# #### 7. Which game from 2018 got the most votes?

# %%
#df.groupby('year').votes.max()
#mask = df.year == 2018
#mask
#df[mask].votes.max()
df_year = df[(df.year == 2018)]
df_year[["name", "votes"]].max()
# Out:
# name     Zootopia: Dreaming People
# votes                      35709.0
# dtype: object

# %% [markdown]
# #### 8. What is the average rating for each genre (Action, Adventure, Comedy, Crime, Family, Fantasy, Mystery, Sci-Fi, and Thriller)?

# %%
genres = ["Action","Adventure","Sci_Fi","Thriller","Comedy","Family","Crime","Fantasy","Mystery"]

for genre in genres:
    print(f'{genre} rating mean:',(df[df[genre]].rating.mean()))
# Out:
# Action rating mean: 7.069257468699611
# Adventure rating mean: 7.2494638480392135
# Sci_Fi rating mean: 6.9492544492544575
# Thriller rating mean: 7.1071428571428585
# Comedy rating mean: 7.189196197061372
# Family rating mean: 6.686450381679379
# Crime rating mean: 7.315111111111107
# Fantasy rating mean: 7.261732229123556
# Mystery rating mean: 7.4513286713286675

# %% [markdown]
# #### 9. Which year's games received the most votes?

# %%
df.groupby('year')[['votes']].max().sort_values(['votes'], ascending=False)
#df_game = df.groupby('year').votes.max()
#df_game
# Out:
#           votes
# year
# 2013.0  60597.0
# 2004.0  39632.0
# 2018.0  35709.0
# 2008.0  34555.0
# 2011.0  30766.0
# ...         ...
# 1964.0      NaN
# 2023.0      NaN
# 2024.0      NaN
# 2025.0      NaN
# 2027.0      NaN
#
# [61 rows x 1 columns]

# %% [markdown]
# #### 10. What's the average number of votes for games that are not Action games?

# %%
#df.groupby(['Adventure','Comedy','Crime','Family','Fantasy','Mystery','Sci_Fi','Thriller']).votes.mean()
df.groupby('Action').votes.agg(['mean'])
# Out:
#               mean
# Action
# False   188.427157
# True    824.919797

# %% [markdown]
# #### 11. What games are platformers?

# %%
games = df[df.plot_summary.str.contains("platformers")]
games
# Out:
#        Unnamed: 0              name  \
# 8927         8925            Oniken
# 9545         9543      Rise & Shine
# 13314       13312      Mutant Mudds
# 13530       13528  Land of Illusion
#
#                                                      url    year certificate  \
# 8927   https://www.imdb.com/title/tt18115072/?ref_=ad...  2012.0           T
# 9545   https://www.imdb.com/title/tt11494552/?ref_=ad...  2017.0           M
# 13314  https://www.imdb.com/title/tt17158468/?ref_=ad...  2012.0           E
# 13530  https://www.imdb.com/title/tt0462394/?ref_=adv...  1993.0   Not Rated
#
#        rating  votes                                       plot_summary  \
# 8927      NaN    NaN  In a post-apocalyptic future controlled by a s...
# 9545      6.8    5.0  Rise and Shine is a true "think and gun" that ...
# 13314     NaN    NaN  Love pixels and platformers? Is there a specia...
# 13530     7.3   46.0  The third entry in Mickey Mouse's 'Illusion' s...
#
# ...

# %% [markdown]
# #### 12. What is the most common certificate of games with ratings greater than 8.0 and votes greater than 1000?

# %%
# section it to games with ratings greater than 8.0 and votes greater than 1000
    # do i need to use mode to find the most common
#df.groupby('Sci_Fi')['certificate'].agg(pd.Series.mode)
common_certificate = df[(df.rating > 8.0) & (df.votes > 1000)]
common_certificate.certificate.value_counts()
# Out:
# M            363
# T            180
# E            102
# E10+          51
# K-A           13
# AO             1
# Unrated        1
# Not Rated      1
# Name: certificate, dtype: int64

# %% [markdown]
# #### 13. For games with ratings greater than the 75th percentile for ratings and a number of votes greater than the 75th percentile for votes, what is the most common genre?

# %%
# saving as a variable because you want to use it later
# takeaway (how to frame the question)
rating_threshold = df.rating.quantile(0.75)
votes_threshold = df.votes.quantile(0.75)

genres = ["Action","Adventure","Sci_Fi","Thriller","Comedy","Family","Crime","Fantasy","Mystery"]

# this shortens everything so you don't have to keep writing out the same two 
good_games = df[(df.rating > rating_threshold) & (df.votes > votes_threshold)]
for genre in genres:
    print(genre, len(good_games[good_games[genre]==True] ))


#good_action_games = good_games[good_games.Action==True]
#print("Action", len(good_action_games))

#good_adventure_games = good_games[good_games.Adventure==True]
#len(good_adventure_games)
# Out:
# Action 1102
# Adventure 993
# Sci_Fi 186
# Thriller 55
# Comedy 151
# Family 113
# Crime 150
# Fantasy 443
# Mystery 121

# %% [markdown]
# #### 14. What are the average ratings by year?

# %%
# first section by year and then find the average rating for each year
# can convert a series into a dataframe
pd.DataFrame(df.groupby("year").rating.mean())
# Out:
#           rating
# year
# 1952.0  7.000000
# 1962.0  6.800000
# 1964.0       NaN
# 1969.0  6.950000
# 1970.0  4.300000
# ...          ...
# 2022.0  7.563063
# 2023.0       NaN
# 2024.0       NaN
# 2025.0       NaN
# 2027.0       NaN
#
# [61 rows x 1 columns]

# %% [markdown]
# #### 15. For each certificate, what was the average rating and average number of votes?

# %%
# first group by certificate
certificate_votes = df.groupby('certificate')[['votes','rating']].mean()
print(certificate_votes)
# Out:
#                    votes    rating
# certificate
# 12             31.375000  7.350000
# AO            246.333333  6.493333
# Approved       52.333333  6.900000
# CE             12.600000  5.520000
# E             332.329063  7.085637
# E10+          520.265766  7.181231
# EC             18.857143  6.142857
# G              11.500000  5.600000
# GA            165.105263  6.531579
# K-A           349.324607  6.913089
# M            2498.627557  7.515584
# MA-13          83.200000  7.080000
# MA-17         165.666667  6.000000
# Not Rated     110.759124  6.703650
# PG            106.333333  5.933333
# PG-13         119.000000  6.628571
# Passed         19.000000  4.700000
# T             829.020862  7.295178
# TV-14         127.000000  7.000000
# TV-MA           8.000000  7.000000
# Unrated       135.973333  6.478222
